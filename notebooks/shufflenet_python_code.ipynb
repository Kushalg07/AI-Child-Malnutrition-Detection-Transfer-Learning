# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets, models
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
from torchvision.datasets import ImageFolder
from PIL import Image
from torchvision import models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# If using GPU, check for availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Load ShuffleNetV2 model
model = models.shufflenet_v2_x1_0(pretrained=True)
model.to(device)

# Modify the fully connected layer for binary classification
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 128),
    nn.LeakyReLU(0.01),
    nn.Dropout(0.5),
    nn.Linear(128, 1),
    nn.Sigmoid()
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ShuffleNet_V2_X1_0_Weights.IMAGENET1K_V1`. You can also use `weights=ShuffleNet_V2_X1_0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to /root/.cache/torch/hub/checkpoints/shufflenetv2_x1-5666bf0f80.pth
# 100%|██████████| 8.79M/8.79M [00:00<00:00, 86.0MB/s]

# %%
# Move all model parameters to the specified device
model = model.to(device)

import torchsummary
# Print the model summary
torchsummary.summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 24, 112, 112]             648
#        BatchNorm2d-2         [-1, 24, 112, 112]              48
#               ReLU-3         [-1, 24, 112, 112]               0
#          MaxPool2d-4           [-1, 24, 56, 56]               0
#             Conv2d-5           [-1, 24, 28, 28]             216
#        BatchNorm2d-6           [-1, 24, 28, 28]              48
#             Conv2d-7           [-1, 58, 28, 28]           1,392
#        BatchNorm2d-8           [-1, 58, 28, 28]             116
#               ReLU-9           [-1, 58, 28, 28]               0
#            Conv2d-10           [-1, 58, 56, 56]           1,392
#       BatchNorm2d-11           [-1, 58, 56, 56]             116
#              ReLU-12           [-1, 58, 56, 56]               0
#            Conv2d-13           [-1, 58, 28, 28]             522
#       BatchNorm2d-14           [-1, 58, 28, 28]             116
#            Conv2d-15           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-16           [-1, 58, 28, 28]             116
#              ReLU-17           [-1, 58, 28, 28]               0
#  InvertedResidual-18          [-1, 116, 28, 28]               0
#            Conv2d-19           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-20           [-1, 58, 28, 28]             116
#              ReLU-21           [-1, 58, 28, 28]               0
#            Conv2d-22           [-1, 58, 28, 28]             522
#       BatchNorm2d-23           [-1, 58, 28, 28]             116
#            Conv2d-24           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-25           [-1, 58, 28, 28]             116
#              ReLU-26           [-1, 58, 28, 28]               0
#  InvertedResidual-27          [-1, 116, 28, 28]               0
#            Conv2d-28           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-29           [-1, 58, 28, 28]             116
#              ReLU-30           [-1, 58, 28, 28]               0
#            Conv2d-31           [-1, 58, 28, 28]             522
#       BatchNorm2d-32           [-1, 58, 28, 28]             116
#            Conv2d-33           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-34           [-1, 58, 28, 28]             116
#              ReLU-35           [-1, 58, 28, 28]               0
#  InvertedResidual-36          [-1, 116, 28, 28]               0
#            Conv2d-37           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-38           [-1, 58, 28, 28]             116
#              ReLU-39           [-1, 58, 28, 28]               0
#            Conv2d-40           [-1, 58, 28, 28]             522
#       BatchNorm2d-41           [-1, 58, 28, 28]             116
#            Conv2d-42           [-1, 58, 28, 28]           3,364
#       BatchNorm2d-43           [-1, 58, 28, 28]             116
#              ReLU-44           [-1, 58, 28, 28]               0
#  InvertedResidual-45          [-1, 116, 28, 28]               0
#            Conv2d-46          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-47          [-1, 116, 14, 14]             232
#            Conv2d-48          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-49          [-1, 116, 14, 14]             232
#              ReLU-50          [-1, 116, 14, 14]               0
#            Conv2d-51          [-1, 116, 28, 28]          13,456
#       BatchNorm2d-52          [-1, 116, 28, 28]             232
#              ReLU-53          [-1, 116, 28, 28]               0
#            Conv2d-54          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-55          [-1, 116, 14, 14]             232
#            Conv2d-56          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-57          [-1, 116, 14, 14]             232
#              ReLU-58          [-1, 116, 14, 14]               0
#  InvertedResidual-59          [-1, 232, 14, 14]               0
#            Conv2d-60          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-61          [-1, 116, 14, 14]             232
#              ReLU-62          [-1, 116, 14, 14]               0
#            Conv2d-63          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-64          [-1, 116, 14, 14]             232
#            Conv2d-65          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-66          [-1, 116, 14, 14]             232
#              ReLU-67          [-1, 116, 14, 14]               0
#  InvertedResidual-68          [-1, 232, 14, 14]               0
#            Conv2d-69          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-70          [-1, 116, 14, 14]             232
#              ReLU-71          [-1, 116, 14, 14]               0
#            Conv2d-72          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-73          [-1, 116, 14, 14]             232
#            Conv2d-74          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-75          [-1, 116, 14, 14]             232
#              ReLU-76          [-1, 116, 14, 14]               0
#  InvertedResidual-77          [-1, 232, 14, 14]               0
#            Conv2d-78          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-79          [-1, 116, 14, 14]             232
#              ReLU-80          [-1, 116, 14, 14]               0
#            Conv2d-81          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-82          [-1, 116, 14, 14]             232
#            Conv2d-83          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-84          [-1, 116, 14, 14]             232
#              ReLU-85          [-1, 116, 14, 14]               0
#  InvertedResidual-86          [-1, 232, 14, 14]               0
#            Conv2d-87          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-88          [-1, 116, 14, 14]             232
#              ReLU-89          [-1, 116, 14, 14]               0
#            Conv2d-90          [-1, 116, 14, 14]           1,044
#       BatchNorm2d-91          [-1, 116, 14, 14]             232
#            Conv2d-92          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-93          [-1, 116, 14, 14]             232
#              ReLU-94          [-1, 116, 14, 14]               0
#  InvertedResidual-95          [-1, 232, 14, 14]               0
#            Conv2d-96          [-1, 116, 14, 14]          13,456
#       BatchNorm2d-97          [-1, 116, 14, 14]             232
#              ReLU-98          [-1, 116, 14, 14]               0
#            Conv2d-99          [-1, 116, 14, 14]           1,044
#      BatchNorm2d-100          [-1, 116, 14, 14]             232
#           Conv2d-101          [-1, 116, 14, 14]          13,456
#      BatchNorm2d-102          [-1, 116, 14, 14]             232
#             ReLU-103          [-1, 116, 14, 14]               0
# InvertedResidual-104          [-1, 232, 14, 14]               0
#           Conv2d-105          [-1, 116, 14, 14]          13,456
#      BatchNorm2d-106          [-1, 116, 14, 14]             232
#             ReLU-107          [-1, 116, 14, 14]               0
#           Conv2d-108          [-1, 116, 14, 14]           1,044
#      BatchNorm2d-109          [-1, 116, 14, 14]             232
#           Conv2d-110          [-1, 116, 14, 14]          13,456
#      BatchNorm2d-111          [-1, 116, 14, 14]             232
#             ReLU-112          [-1, 116, 14, 14]               0
# InvertedResidual-113          [-1, 232, 14, 14]               0
#           Conv2d-114          [-1, 116, 14, 14]          13,456
#      BatchNorm2d-115          [-1, 116, 14, 14]             232
#             ReLU-116          [-1, 116, 14, 14]               0
#           Conv2d-117          [-1, 116, 14, 14]           1,044
#      BatchNorm2d-118          [-1, 116, 14, 14]             232
#           Conv2d-119          [-1, 116, 14, 14]          13,456
#      BatchNorm2d-120          [-1, 116, 14, 14]             232
#             ReLU-121          [-1, 116, 14, 14]               0
# InvertedResidual-122          [-1, 232, 14, 14]               0
#           Conv2d-123            [-1, 232, 7, 7]           2,088
#      BatchNorm2d-124            [-1, 232, 7, 7]             464
#           Conv2d-125            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-126            [-1, 232, 7, 7]             464
#             ReLU-127            [-1, 232, 7, 7]               0
#           Conv2d-128          [-1, 232, 14, 14]          53,824
#      BatchNorm2d-129          [-1, 232, 14, 14]             464
#             ReLU-130          [-1, 232, 14, 14]               0
#           Conv2d-131            [-1, 232, 7, 7]           2,088
#      BatchNorm2d-132            [-1, 232, 7, 7]             464
#           Conv2d-133            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-134            [-1, 232, 7, 7]             464
#             ReLU-135            [-1, 232, 7, 7]               0
# InvertedResidual-136            [-1, 464, 7, 7]               0
#           Conv2d-137            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-138            [-1, 232, 7, 7]             464
#             ReLU-139            [-1, 232, 7, 7]               0
#           Conv2d-140            [-1, 232, 7, 7]           2,088
#      BatchNorm2d-141            [-1, 232, 7, 7]             464
#           Conv2d-142            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-143            [-1, 232, 7, 7]             464
#             ReLU-144            [-1, 232, 7, 7]               0
# InvertedResidual-145            [-1, 464, 7, 7]               0
#           Conv2d-146            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-147            [-1, 232, 7, 7]             464
#             ReLU-148            [-1, 232, 7, 7]               0
#           Conv2d-149            [-1, 232, 7, 7]           2,088
#      BatchNorm2d-150            [-1, 232, 7, 7]             464
#           Conv2d-151            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-152            [-1, 232, 7, 7]             464
#             ReLU-153            [-1, 232, 7, 7]               0
# InvertedResidual-154            [-1, 464, 7, 7]               0
#           Conv2d-155            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-156            [-1, 232, 7, 7]             464
#             ReLU-157            [-1, 232, 7, 7]               0
#           Conv2d-158            [-1, 232, 7, 7]           2,088
#      BatchNorm2d-159            [-1, 232, 7, 7]             464
#           Conv2d-160            [-1, 232, 7, 7]          53,824
#      BatchNorm2d-161            [-1, 232, 7, 7]             464
#             ReLU-162            [-1, 232, 7, 7]               0
# InvertedResidual-163            [-1, 464, 7, 7]               0
#           Conv2d-164           [-1, 1024, 7, 7]         475,136
#      BatchNorm2d-165           [-1, 1024, 7, 7]           2,048
#             ReLU-166           [-1, 1024, 7, 7]               0
#           Linear-167                  [-1, 128]         131,200
#        LeakyReLU-168                  [-1, 128]               0
#          Dropout-169                  [-1, 128]               0
#           Linear-170                    [-1, 1]             129
#          Sigmoid-171                    [-1, 1]               0
# ================================================================
# Total params: 1,384,933
# Trainable params: 1,384,933
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 47.93
# Params size (MB): 5.28
# Estimated Total Size (MB): 53.79
# ----------------------------------------------------------------

# %%
# You can set the paths to your train and test data folders
train_data_path = "/content/drive/MyDrive/Dataset/DataSet_Malnutrtion/train"
test_data_path = "/content/drive/MyDrive/Dataset/DataSet_Malnutrtion/val"

# Data transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the train and test datasets
train_dataset = ImageFolder(train_data_path, transform=transform)
test_dataset = ImageFolder(test_data_path, transform=transform)

# Data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Loss function
criterion = nn.BCELoss()

# Optimizer with Weight decay
# SGD optimizer with momentum and weight decay
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.01)

# Learning rate scheduling (reduce learning rate on plateau)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=5, verbose=True)

# Initialize lists to store training and validation losses and accuracies
training_losses = []
validation_losses = []
training_accuracies = []
validation_accuracies = []

# Define the number of epochs
num_epochs = 100

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.float().to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels.unsqueeze(1))
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

        predicted = (outputs > 0.5).float()
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels.unsqueeze(1)).sum().item()

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_accuracy = (correct_predictions / total_predictions) * 100

    training_losses.append(epoch_loss)
    training_accuracies.append(epoch_accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_accuracy:.2f}%")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    validation_loss = 0.0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.float().to(device)
            outputs = model(images)
            loss = criterion(outputs, labels.unsqueeze(1))
            validation_loss += loss.item() * images.size(0)

            predicted = (outputs > 0.5).float()
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels.unsqueeze(1)).sum().item()

    avg_val_loss = validation_loss / len(test_loader.dataset)
    validation_losses.append(avg_val_loss)

    # Calculate accuracy for this epoch's validation
    epoch_accuracy = (correct_predictions / total_predictions) * 100
    validation_accuracies.append(epoch_accuracy)

    print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {epoch_accuracy:.2f}%")

    # Adjust learning rate based on validation loss
    scheduler.step(avg_val_loss)
# Out:
# Epoch [1/100], Loss: 0.6860, Training Accuracy: 62.92%
# Validation Loss: 0.6866, Validation Accuracy: 57.29%
# Epoch [2/100], Loss: 0.6644, Training Accuracy: 70.80%
# Validation Loss: 0.6824, Validation Accuracy: 57.29%
# Epoch [3/100], Loss: 0.6481, Training Accuracy: 70.80%
# Validation Loss: 0.6811, Validation Accuracy: 57.29%
# Epoch [4/100], Loss: 0.6358, Training Accuracy: 70.80%
# Validation Loss: 0.6817, Validation Accuracy: 57.29%
# Epoch [5/100], Loss: 0.6274, Training Accuracy: 70.80%
# Validation Loss: 0.6833, Validation Accuracy: 57.29%
# Epoch [6/100], Loss: 0.6205, Training Accuracy: 70.80%
# Validation Loss: 0.6857, Validation Accuracy: 57.29%
# Epoch [7/100], Loss: 0.6157, Training Accuracy: 70.80%
# Validation Loss: 0.6883, Validation Accuracy: 57.29%
# Epoch [8/100], Loss: 0.6122, Training Accuracy: 70.80%
# Validation Loss: 0.6910, Validation Accuracy: 57.29%
# Epoch [9/100], Loss: 0.6091, Training Accuracy: 70.80%
# Validation Loss: 0.6934, Validation Accuracy: 57.29%
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [10/100], Loss: 0.6073, Training Accuracy: 70.80%
# Validation Loss: 0.6945, Validation Accuracy: 57.29%
# Epoch [11/100], Loss: 0.6063, Training Accuracy: 70.80%
# Validation Loss: 0.6959, Validation Accuracy: 57.29%
# Epoch [12/100], Loss: 0.6058, Training Accuracy: 70.80%
# Validation Loss: 0.6969, Validation Accuracy: 57.29%
# Epoch [13/100], Loss: 0.6047, Training Accuracy: 70.80%
# Validation Loss: 0.6981, Validation Accuracy: 57.29%
# Epoch [14/100], Loss: 0.6048, Training Accuracy: 70.80%
# Validation Loss: 0.6991, Validation Accuracy: 57.29%
# Epoch [15/100], Loss: 0.6046, Training Accuracy: 70.80%
# Validation Loss: 0.6999, Validation Accuracy: 57.29%
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [16/100], Loss: 0.6032, Training Accuracy: 70.80%
# Validation Loss: 0.7002, Validation Accuracy: 57.29%
# Epoch [17/100], Loss: 0.6028, Training Accuracy: 70.80%
# Validation Loss: 0.7008, Validation Accuracy: 57.29%
# Epoch [18/100], Loss: 0.6036, Training Accuracy: 70.80%
# Validation Loss: 0.7011, Validation Accuracy: 57.29%
# Epoch [19/100], Loss: 0.6027, Training Accuracy: 70.80%
# Validation Loss: 0.7017, Validation Accuracy: 57.29%
# Epoch [20/100], Loss: 0.6024, Training Accuracy: 70.80%
# Validation Loss: 0.7019, Validation Accuracy: 57.29%
# Epoch [21/100], Loss: 0.6016, Training Accuracy: 70.80%
# Validation Loss: 0.7024, Validation Accuracy: 57.29%
# Epoch 00021: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [22/100], Loss: 0.6017, Training Accuracy: 70.80%
# Validation Loss: 0.7025, Validation Accuracy: 57.29%
# Epoch [23/100], Loss: 0.6023, Training Accuracy: 70.80%
# Validation Loss: 0.7029, Validation Accuracy: 57.29%
# Epoch [24/100], Loss: 0.6022, Training Accuracy: 70.80%
# Validation Loss: 0.7029, Validation Accuracy: 57.29%
# Epoch [25/100], Loss: 0.6019, Training Accuracy: 70.80%
# Validation Loss: 0.7031, Validation Accuracy: 57.29%
# Epoch [26/100], Loss: 0.6018, Training Accuracy: 70.80%
# Validation Loss: 0.7031, Validation Accuracy: 57.29%
# Epoch [27/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7034, Validation Accuracy: 57.29%
# Epoch 00027: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [28/100], Loss: 0.6006, Training Accuracy: 70.80%
# Validation Loss: 0.7034, Validation Accuracy: 57.29%
# Epoch [29/100], Loss: 0.6021, Training Accuracy: 70.80%
# Validation Loss: 0.7036, Validation Accuracy: 57.29%
# Epoch [30/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7036, Validation Accuracy: 57.29%
# Epoch [31/100], Loss: 0.6016, Training Accuracy: 70.80%
# Validation Loss: 0.7037, Validation Accuracy: 57.29%
# Epoch [32/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7037, Validation Accuracy: 57.29%
# Epoch [33/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7039, Validation Accuracy: 57.29%
# Epoch 00033: reducing learning rate of group 0 to 3.1250e-05.
# Epoch [34/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7038, Validation Accuracy: 57.29%
# Epoch [35/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7039, Validation Accuracy: 57.29%
# Epoch [36/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [37/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [38/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [39/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch 00039: reducing learning rate of group 0 to 1.5625e-05.
# Epoch [40/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [41/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [42/100], Loss: 0.6014, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [43/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7040, Validation Accuracy: 57.29%
# Epoch [44/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [45/100], Loss: 0.6018, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch 00045: reducing learning rate of group 0 to 7.8125e-06.
# Epoch [46/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [47/100], Loss: 0.6004, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [48/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [49/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [50/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [51/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch 00051: reducing learning rate of group 0 to 3.9063e-06.
# Epoch [52/100], Loss: 0.6014, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [53/100], Loss: 0.6014, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [54/100], Loss: 0.6006, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [55/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [56/100], Loss: 0.6014, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [57/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch 00057: reducing learning rate of group 0 to 1.9531e-06.
# Epoch [58/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [59/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [60/100], Loss: 0.6013, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [61/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [62/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [63/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch 00063: reducing learning rate of group 0 to 9.7656e-07.
# Epoch [64/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [65/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [66/100], Loss: 0.6016, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch [67/100], Loss: 0.6017, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [68/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [69/100], Loss: 0.6006, Training Accuracy: 70.80%
# Validation Loss: 0.7045, Validation Accuracy: 57.29%
# Epoch 00069: reducing learning rate of group 0 to 4.8828e-07.
# Epoch [70/100], Loss: 0.6012, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [71/100], Loss: 0.6012, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [72/100], Loss: 0.6006, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [73/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch [74/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [75/100], Loss: 0.6009, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch 00075: reducing learning rate of group 0 to 2.4414e-07.
# Epoch [76/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [77/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [78/100], Loss: 0.6016, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch [79/100], Loss: 0.6014, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [80/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [81/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch 00081: reducing learning rate of group 0 to 1.2207e-07.
# Epoch [82/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [83/100], Loss: 0.6012, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [84/100], Loss: 0.6010, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [85/100], Loss: 0.6003, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [86/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [87/100], Loss: 0.6004, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch 00087: reducing learning rate of group 0 to 6.1035e-08.
# Epoch [88/100], Loss: 0.6012, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch [89/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [90/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [91/100], Loss: 0.6004, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [92/100], Loss: 0.6009, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [93/100], Loss: 0.6009, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch 00093: reducing learning rate of group 0 to 3.0518e-08.
# Epoch [94/100], Loss: 0.6007, Training Accuracy: 70.80%
# Validation Loss: 0.7044, Validation Accuracy: 57.29%
# Epoch [95/100], Loss: 0.6015, Training Accuracy: 70.80%
# Validation Loss: 0.7041, Validation Accuracy: 57.29%
# Epoch [96/100], Loss: 0.6006, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch [97/100], Loss: 0.6005, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [98/100], Loss: 0.6011, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%
# Epoch [99/100], Loss: 0.6008, Training Accuracy: 70.80%
# Validation Loss: 0.7042, Validation Accuracy: 57.29%
# Epoch 00099: reducing learning rate of group 0 to 1.5259e-08.
# Epoch [100/100], Loss: 0.6012, Training Accuracy: 70.80%
# Validation Loss: 0.7043, Validation Accuracy: 57.29%

# %%
# Evaluate the model on the test set
model.eval()
true_labels = []
predicted_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.float().to(device)
        outputs = model(images)
        predicted = (outputs > 0.5).float()

        true_labels.extend(labels.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Generate the classification report and confusion matrix
class_names = ['Healthy', 'Unhealthy']
report = classification_report(predicted_labels, true_labels, target_names=class_names)
accuracy = accuracy_score(true_labels, predicted_labels) * 100
print(f"Accuracy: {accuracy:.2f}%")
print(report)
# Out:
# Accuracy: 57.29%
#               precision    recall  f1-score   support
#
#      Healthy       0.00      0.00      0.00         0
#    Unhealthy       1.00      0.57      0.73       295
#
#     accuracy                           0.57       295
#    macro avg       0.50      0.29      0.36       295
# weighted avg       1.00      0.57      0.73       295
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

import numpy as np
# Assuming predicted_labels is a list, convert it to a NumPy array
predicted_labels_np = np.array(predicted_labels)

# Set the threshold for binary classification
threshold = 0.5

# Apply the threshold to convert probabilities to binary predictions
binary_predictions = (predicted_labels_np > threshold).astype(int)

# Confusion Matrix
cm = confusion_matrix(true_labels, binary_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Plot training and validation losses
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(training_losses, label="Training Loss")
plt.plot(validation_losses, label="Validation Loss")
plt.title("Training and Validation Losses")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(training_accuracies, label="Training Accuracy", color="green")
plt.plot(validation_accuracies, label="Validation Accuracy", color="blue")
plt.title("Training and Validation Accuracies")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate AUC and plot ROC curve
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

print(f"AUC: {roc_auc:.4f}")
# Out:
# AUC: 0.5000
